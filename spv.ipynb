# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import altair as alt

# %matplotlib inline

# %%
days = 20
tickers = {
        "apple": "AAPL",
        "akerna": "KERN",
        "amazon": "AMZN",
        "aurora": "ACB",
        "aphria": "APHA",
        "afc": "AFGC",
        "cronos": "CRON",
        "facebook": "FB",
        "google": "GOOGL",
        "gw_pharmaceuticals": "GWPH",
        "innovative": "IIPR",
        "microsoft": "MSFT",
        "medicine_man": "SHWZ",
        "molson coors": "TAP",
        "cinstellation": "STZ",
        "netflix": "NFLX",
        "tesla": "TSLA",
        "tilray": "TLRY",
        "trevena": "TRVN",
        "triton": "TRTN",
}
def get_data(days, tickers):
    df = pd.DataFrame()
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company])
        hist = tkr.history(period=f'{days}d')
        hist.index =hist.index.strftime('%d %B %Y')
        hist = hist[['Close']]
        hist.columns = [company]
        hist = hist.T
        hist.index.name = 'Name'
        df = pd.concat([df, hist])
    return df

get_data(days, tickers)
# Out:
# Date                19 March 2021  22 March 2021  23 March 2021  \
# Name
# apple                  119.989998     123.389999     122.540001
# akerna                   5.420000       5.030000       4.900000
# amazon                3074.959961    3110.870117    3137.500000
# aurora                  10.140000       9.700000       9.320000
# aphria                  19.340000      18.760000      18.120001
# afc                     26.340000      26.450001      26.570000
# cronos                  10.150000       9.750000       9.540000
# facebook               290.109985     293.540009     290.630005
# google                2026.959961    2030.689941    2041.329956
# gw_pharmaceuticals     215.250000     215.330002     214.360001
# innovative             176.888306     174.268326     171.023117
# microsoft              230.350006     235.990005     237.580002
# medicine_man             2.420000       2.364000       2.330000
# molson coors            49.200001      49.849998      48.790001
# ...

# %%
# 株価周辺情報

yf.Ticker(tickers['innovative']).info # 会社情報
# Out:
# {'zip': '92127',
#  'sector': 'Real Estate',
#  'fullTimeEmployees': 15,
#  'longBusinessSummary': 'Innovative Industrial Properties, Inc. is a self-advised Maryland corporation focused on the acquisition, ownership and management of specialized properties leased to experienced, state-licensed operators for their regulated medical-use cannabis facilities. Innovative Industrial Properties, Inc. has elected to be taxed as a real estate investment trust, commencing with the year ended December 31, 2017.',
#  'city': 'San Diego',
#  'phone': '858-997-3332',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.innovativeindustrialproperties.com',
#  'maxAge': 1,
#  'address1': '11440 West Bernardo Court',
#  'industry': 'REIT—Industrial',
#  'address2': 'Suite 220',
#  'previousClose': 183.54,
#  'regularMarketOpen': 185.51,
#  'twoHundredDayAverage': 171.32979,
#  'trailingAnnualDividendYield': 0.024354365,
#  'payoutRatio': 1.367,
# ...

# %%
yf.Ticker(tickers['apple']).actions.head()
# Out:
#             Dividends  Stock Splits
# Date
# 1987-05-11   0.000536           0.0
# 1987-06-16   0.000000           2.0
# 1987-08-10   0.000536           0.0
# 1987-11-17   0.000714           0.0
# 1988-02-12   0.000714           0.0

# %%
yf.Ticker(tickers['apple']).dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%